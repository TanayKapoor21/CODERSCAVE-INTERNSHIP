# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# IMPORTING THE DATA

# %%
df = pd.read_csv("Hackathon_Ideal_Data.csv")

# %% [markdown]
# EXPLORING THE DATA

# %%
df.shape
# Out:
# (14260, 10)

# %%
df
# Out:
#       MONTH STORECODE  QTY  VALUE                       GRP  \
# 0        M1        P1   25     83         HAIR CONDITIONERS
# 1        M1        P1    6     22         HAIR CONDITIONERS
# 2        M1        P1    4     15         HAIR CONDITIONERS
# 3        M1        P1   15     60         HAIR CONDITIONERS
# 4        M1        P2    0      0         HAIR CONDITIONERS
# ...     ...       ...  ...    ...                       ...
# 14255    M3       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14256    M3        P8    1     62  SUGAR SUBSTITUTE (11/05)
# 14257    M1        P6    0      0  SUGAR SUBSTITUTE (11/05)
# 14258    M1       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14259    M1        P8    1     62  SUGAR SUBSTITUTE (11/05)
#
#                         SGRP                  SSGRP  \
# 0          HAIR CONDITIONERS      HAIR CONDITIONERS
# 1          HAIR CONDITIONERS      HAIR CONDITIONERS
# 2          HAIR CONDITIONERS      HAIR CONDITIONERS
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       MONTH STORECODE  QTY  VALUE                       GRP  \
# 0        M1        P1   25     83         HAIR CONDITIONERS
# 1        M1        P1    6     22         HAIR CONDITIONERS
# 2        M1        P1    4     15         HAIR CONDITIONERS
# 3        M1        P1   15     60         HAIR CONDITIONERS
# 4        M1        P2    0      0         HAIR CONDITIONERS
# ...     ...       ...  ...    ...                       ...
# 14255    M3       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14256    M3        P8    1     62  SUGAR SUBSTITUTE (11/05)
# 14257    M1        P6    0      0  SUGAR SUBSTITUTE (11/05)
# 14258    M1       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14259    M1        P8    1     62  SUGAR SUBSTITUTE (11/05)
#
#                         SGRP                  SSGRP  \
# 0          HAIR CONDITIONERS      HAIR CONDITIONERS
# 1          HAIR CONDITIONERS      HAIR CONDITIONERS
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       MONTH STORECODE  QTY  VALUE                       GRP  \
# 0        M1        P1   25     83         HAIR CONDITIONERS
# 1        M1        P1    6     22         HAIR CONDITIONERS
# 2        M1        P1    4     15         HAIR CONDITIONERS
# 3        M1        P1   15     60         HAIR CONDITIONERS
# 4        M1        P2    0      0         HAIR CONDITIONERS
# ...     ...       ...  ...    ...                       ...
# 14255    M3       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14256    M3        P8    1     62  SUGAR SUBSTITUTE (11/05)
# 14257    M1        P6    0      0  SUGAR SUBSTITUTE (11/05)
# 14258    M1       P10    0      0  SUGAR SUBSTITUTE (11/05)
# 14259    M1        P8    1     62  SUGAR SUBSTITUTE (11/05)
#
#                         SGRP                  SSGRP  \
# 0          HAIR CONDITIONERS      HAIR CONDITIONERS
# 1          HAIR CONDITIONERS      HAIR CONDITIONERS
# 2          HAIR CONDITIONERS      HAIR CONDITIONERS
# ...

# %%
df.columns
# Out:
# Index(['MONTH', 'STORECODE', 'QTY', 'VALUE', 'GRP', 'SGRP', 'SSGRP', 'CMP',
#        'MBRD', 'BRD'],
#       dtype='object')

# %%
df.nunique()
# Out:
# MONTH           3
# STORECODE      10
# QTY           258
# VALUE        1606
# GRP            80
# SGRP          177
# SSGRP         242
# CMP           512
# MBRD          818
# BRD          1613
# dtype: int64

# %%
cat_col=[]
for i in df.columns:
    if(df[i].dtypes=='object'):
        cat_col.append(i)
print(cat_col)
# Out:
# ['MONTH', 'STORECODE', 'GRP', 'SGRP', 'SSGRP', 'CMP', 'MBRD', 'BRD']

# %%
df.isnull()
# Out:
#        MONTH  STORECODE    QTY  VALUE    GRP   SGRP  SSGRP    CMP   MBRD  \
# 0      False      False  False  False  False  False  False  False  False
# 1      False      False  False  False  False  False  False  False  False
# 2      False      False  False  False  False  False  False  False  False
# 3      False      False  False  False  False  False  False  False  False
# 4      False      False  False  False  False  False  False  False  False
# ...      ...        ...    ...    ...    ...    ...    ...    ...    ...
# 14255  False      False  False  False  False  False  False  False  False
# 14256  False      False  False  False  False  False  False  False  False
# 14257  False      False  False  False  False  False  False  False  False
# 14258  False      False  False  False  False  False  False  False  False
# 14259  False      False  False  False  False  False  False  False  False
#
#          BRD
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.figure(facecolor='white')
plt.figure(figsize=(10, 6))
sns.histplot(df['QTY'], bins=30, kde=False)
plt.title('Distribution of Sales Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frequency')
plt.show()

# %%
df[['VALUE']].boxplot()
# Out:
# <Axes: >

# %% [markdown]
# IMPORTING DATASET 2

# %%
df1 = pd.read_csv("Hackathon_Working_Data.csv")

# %%
df1
# Out:
#       MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0        M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1        M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2        M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3        M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4        M1        N1    4    T384      19.0  1.0   19.0   19.0
# ...     ...       ...  ...     ...       ...  ...    ...    ...
# 26980    M3       N10   31   T5999      10.0  1.0   10.0   10.0
# 26981    M3       N10   31   T6007      88.0  1.0   10.0   10.0
# 26982    M3       N10   31   T6007      88.0  2.0   20.0   10.0
# 26983    M3       N10   31   T6007      88.0  1.0   58.0   58.0
# 26984    M3       N10   31   T6013      15.0  1.0   15.0   15.0
#
#                               GRP                     SGRP  \
# 0            BUTTER MARGR  (4/94)                   BUTTER
# 1         CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# ...

# %% [markdown]
# EXPLORING THE DATASET

# %%
df1.head()
# Out:
#   MONTH STORECODE  DAY BILL_ID  BILL_AMT  QTY  VALUE  PRICE  \
# 0    M1        N1    4    T375     225.0  1.0  225.0  225.0
# 1    M1        N1    4    T379      95.0  1.0   95.0   95.0
# 2    M1        N1    4    T381      10.0  1.0   10.0   10.0
# 3    M1        N1    4    T382     108.0  1.0  108.0  108.0
# 4    M1        N1    4    T384      19.0  1.0   19.0   19.0
#
#                        GRP                     SGRP                    SSGRP  \
# 0     BUTTER MARGR  (4/94)                   BUTTER                   SALTED
# 1  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS  CONFECTIONERY - ECLAIRS
# 2                CHOCOLATE         CHOCOLATE PANNED         CHOCOLATE PANNED
# 3             PACKAGED TEA               MAIN PACKS               MAIN PACKS
# 4         ALL IODISED SALT            POWDERED SALT            POWDERED SALT
#
#                       CMP           MBRD                 BRD
# 0               G C M M F           AMUL                AMUL
# ...

# %%
df1.describe()
# Out:
#                 DAY      BILL_AMT           QTY         VALUE         PRICE
# count  26985.000000  26985.000000  26985.000000  26985.000000  26985.000000
# mean      15.167019    278.754206      4.105021     67.808551     52.812982
# std        8.956057    541.398504     95.666947    118.005978     84.987730
# min        1.000000      0.000000      0.500000      0.000000      0.000000
# 25%        7.000000     40.000000      1.000000     10.000000     10.000000
# 50%       14.000000    111.000000      1.000000     30.000000     22.000000
# 75%       23.000000    280.000000      2.000000     80.000000     64.000000
# max       31.000000   7292.000000  12000.000000   3150.000000   3150.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26985 entries, 0 to 26984
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      26985 non-null  object
#  1   STORECODE  26985 non-null  object
#  2   DAY        26985 non-null  int64
#  3   BILL_ID    26985 non-null  object
#  4   BILL_AMT   26985 non-null  float64
#  5   QTY        26985 non-null  float64
#  6   VALUE      26985 non-null  float64
#  7   PRICE      26985 non-null  float64
#  8   GRP        26985 non-null  object
#  9   SGRP       26985 non-null  object
#  10  SSGRP      26985 non-null  object
#  11  CMP        26985 non-null  object
#  12  MBRD       26985 non-null  object
#  13  BRD        26985 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.9+ MB

# %%
num_col=[]
for i in df.columns:
    if(df[i].dtypes!='object'):
        num_col.append(i)
print(num_col)
# Out:
# ['QTY', 'VALUE']

# %%
cat_col=[]
for i in df.columns:
    if(df[i].dtypes=='object'):
        cat_col.append(i)
print(cat_col)
# Out:
# ['MONTH', 'STORECODE', 'GRP', 'SGRP', 'SSGRP', 'CMP', 'MBRD', 'BRD']

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x='MONTH', y='BILL_AMT', data=df1)
plt.title('Sales Trend Overtime')
plt.xlabel('Month')
plt.ylabel('Bill amount')
plt.show()

# %%
col = 'BRD'
i = df[col].value_counts().index
v = df[col].value_counts().values
default_color = '#3498db'
fig, ax = plt.subplots()
ax.pie(v, labels=i, startangle=90, colors=[default_color])
ax.axis('equal')
plt.title(f"Pie Plot of {col}", fontsize=20)
plt.show()

# %%
m_sales = df1.groupby('MONTH').sum()
plt.figure(figsize=(15,10))
sns.barplot(x=m_sales.index,y='BILL_AMT',data=m_sales)
plt.title("Total Sales by Month")
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid(axis='y',color='brown');
plt.show()
# Out:
# C:\Users\Tanay\AppData\Local\Temp\ipykernel_24332\2221357867.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   m_sales = df1.groupby('MONTH').sum()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.barplot(x='STORECODE', y='BILL_AMT', hue='MBRD', data=df1)
plt.title('Store Behaviour')
plt.xlabel('STORECODE')
plt.ylabel('BILL_AMT')
plt.show()

# %% [markdown]
# In conclusion, the EDA conducted on the transactional data not only offered a deeper understanding of customer behavior but also provided actionable insights that can contribute to
# strategic decision-making. Moving forward, leveraging these findings can empower the business to enhance customer satisfaction, optimize operations, and ultimately drive business
# growth. As data continues to be a valuable asset, ongoing analysis and refinement of strategies based on customer behavior insights will be crucial for maintaining a competitive edge
# in the market.
